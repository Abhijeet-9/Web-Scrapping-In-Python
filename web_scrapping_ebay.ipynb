# %%
import csv
import requests
from bs4 import BeautifulSoup
from decimal import Decimal

# %%
query = input('Enter product: ')
free_shipping = input('Enter free shipping: ')
max_price = Decimal(input('Enter maximum price: '))
# Out:
# Enter product: iphone
# Enter free shipping: yes
# Enter maximum price: 60000

# %%
for i in range(1, 5):
	website = requests.get('https://www.ebay.com/sch/i.html?_nkw=' + query +'&_pgn=' + str(i)).text
	soup = BeautifulSoup(website, 'html.parser')
	items = soup.select('.srp-results .s-item')
	for item in items:
		title = item.h3.text
		price = item.select_one('.s-item__price').text
		shipping = item.select_one('.s-item__shipping').text
		price_decimal = Decimal(price.split(' to ')[0][1:])
		if price_decimal <= max_price:
			if free_shipping == 'y':
				if 'Free' in shipping:
					print(f'{title}\n{price}\n{shipping}')
					print('=================================')
			else:
				print(f'{title}\n{price}\n{shipping}')
				print('=================================')
# Out:
#  at&t iphone 11 10 8 7 plus 6s 6 pro max xs xr x se network code Unlock Service
# $6.99
# Free International Shipping
# =================================
# Apple iPhone 12 PRO MAX - 128GB - BLUE - CRICKET - 9765
# $600.00
# +$35.00 shipping
# =================================
# Apple iPhone 11 Pro - 64GB - Space Gray - Factory Unlocked - NO FACE ID
# $310.00
# +$70.00 shipping
# =================================
# New ListingApple iPhone XS - 256GB - Space Gray (Unlocked) A1920 (CDMA + GSM)
# $149.50
# Free International Shipping
# =================================
# New ListingiPhone XS - 64GB - Silver (Unlocked)
# $143.00
# +$21.00 shipping
# =================================
# Apple iPhone XS - 64GB - Space Gray - Carrier Unlocked - CRACKED SCREEN
# $166.00
# +$70.00 shipping
# =================================
# Apple iPhone 11 Pro Max - 256GB - Space Gray - Unlocked - NO EARPIECE
# $505.00
# +$43.00 shipping
# =================================
# iPhone 11 Pro Max 64GB Unlocked Excellent Condition
# $559.99
# +$75.00 shipping
# =================================
# FMI OFF - Apple iPhone 12 Pro Max Pacific Blue 256GB Verizon (Unlocked) A2342
# $399.00
# +$100.00 shipping
# =================================
# Apple iPhone 11 - 64GB - Black (Unlocked) A2111 (CDMA   GSM)
# $315.00
# Free International Shipping
# =================================
# Excellent Condition Apple iPhone 5s Unlocked 16GB Model Verizon At&t Tmobile
# $49.99
# +$13.00 shipping
# =================================
# Apple iPhone 12 Pro Max - 128GB - Gold (T-Mobile)
# $455.00
# +$146.15 shipping
# =================================
# Apple iPhone 11 - 64GB - WHITE - AT&T - READ DESCRIPTION - 2449
# $229.99
# +$35.00 shipping
# =================================
# Apple iPhone 11 - 64GB - Product RED - Factory Unlocked - CRACKED CAMERA
# $283.00
# +$70.00 shipping
# =================================
# Apple iPhone 11 - 64GB - Black - Carrier Unlocked - NO FACE ID
# $273.00
# +$70.00 shipping
# =================================
# Excellent UNLOCKED Apple iPhone 8 - 64GB At&t GOLD Straight Talk Metro PCS
# $134.49
# +$13.00 shipping
# =================================
# New Listingiphone xr Verizon 64gb used
# $122.50
# +$70.95 shipping
# =================================
# Great Condition Apple iPhone 5 - 16/32/64GB - UNLOCKED
# $30.00 to $35.00
# +$13.00 shipping
# =================================
# Apple iPhone 11 Pro Max - 256GB - Space Gray (Unlocked) A2161 (CDMA + GSM)
# $650.00
# +$25.00 shipping
# =================================
# New ListingApple iPhone 13 - 128GB - Midnight (T-Mobile). Excellent Condition. With Extras
# $203.50
# +$15.63 shipping
# =================================
# Apple iPhone 8 256GB iOS Smartphone Unlocked Space Gray
# $102.50
# +$22.00 shipping
# =================================
# Apple iPhone XR **JAILBROKEN **64GB-Black-Unlocked-Excellent!
# $135.50
# +$20.00 shipping
# =================================
# Apple iPhone 7 - 32GB - Rose Gold (AT&T) A1778 (GSM)
# $68.00
# +$16.45 shipping
# =================================
# New ListingApple iPhone XR - 64GB - Verizon- Pre-Owned Very Good Condition
# $103.50
# +$40.85 shipping
# =================================
# Apple iPhone XR (PRODUCT)RED - 64GB - (Unlocked) - Very Nice Condition
# $202.50
# +$54.34 shipping
# =================================
#  AT&T FACTORY UNLOCK SERVICE Factory ATT Unlock Service only Clean iPhone
# $7.98
# Free International Shipping
# =================================
# New ListingApple iPhone 5s - 32GB 16GB - (Unlocked & Sprint) A1533 & A1453 Lot Of 3
# $56.00
# +$21.00 shipping
# =================================
# Apple iPhone XR - 128GB - Coral (Unlocked) (CDMA + GSM) - EXCELLENT
# $250.00
# +$22.00 shipping
# =================================
# New ListingApple iPhone 12 Pro Max (A2342) 256GB - Pacific Blue - Unlocked - Works Globally
# $925.00
# +$42.15 shipping
# =================================
# Apple iPhone XS - 256GB - Silver - Unlocked - BAD TOUCH DISPLAY
# $180.00
# +$70.00 shipping
# =================================
# Apple iPhone 12 Pro - 128GB - Pacific Blue - Factory Unlocked - Cracked Screen
# $542.00
# +$70.00 shipping
# =================================
# Excellent UNLOCKED Silver Apple iPhone 8 - 64GB At&t Straight Talk Metro PCS
# $134.49
# +$13.00 shipping
# =================================
# New ListingApple iPhone XS - 256GB - Space Gray (Unlocked) A1921 (CDMA + GSM)
# $265.00
# +$21.00 shipping
# =================================
# Apple iPhone 11 Pro - 256GB - Midnight Green (Unlocked) (Used) (Fully Working)
# $446.00
# +$21.00 shipping
# =================================
# New ListingApple iPhone 6 - 16GB - Space Gray & Silver (AT&T) A1549 (GSM) Lot Of 2
# $71.00
# +$21.00 shipping
# =================================
# Apple iPhone XS Max - 256GB - Gold (Unlocked) A1921 (CDMA + GSM)
# $265.00
# +$26.50 shipping
# =================================
# Apple iPhone XS - 256GB - Gold (Unlocked) PRISTINE condition
# $248.50
# +$22.00 shipping
# =================================
# Apple iPhone 6 - 16GB -  White , Gold (Unlocked) A1549 Excellent Condition
# $79.00
# +$26.50 shipping
# =================================
# Apple iPhone 11 Pro 64GB 256GB 512GB Unlocked Fair Condition
# $405.99 to $476.99
# +$49.00 shipping
# =================================
# Excellent UNLOCKED Apple iPhone 8 - 64GB At&t Black Straight Talk Metro PCS
# $139.49
# +$13.00 shipping
# =================================
# Disassembled iPhone 1st Gen Teardown With Frame, Deconstructed iPhone 1 Art
# $269.00
# +$71.85 shipping
# =================================
# Apple iPhone 11 Pro Max - 64GB - Space Gray (AT&T)
# $345.00
# +$21.00 shipping
# =================================
# Apple iPhone 8 64GB Unlocked Smartphone AT&T Verizon T-Mobile Factory Unlocked
# $178.98 to $225.98
# +$80.00 shipping
# =================================
# Apple iPhone 5c - 16GB - Blue (Unlocked) A1456 (GSM)
# $46.99
# +$20.00 shipping
# =================================
# Apple iPhone 11 64GB Unlocked 4G LTE Smartphone
# $321.00
# Free International Shipping
# =================================
# Apple iPhone XS Max - 512GB - Space Gray (Unlocked) A1921 (CDMA + GSM)
# $455.55
# +$35.95 shipping
# =================================
# Apple iPhone XR - 128GB - Black (Sprint) A1984 (CDMA + GSM) with box
# $127.50
# +$22.00 shipping
# =================================
# Apple iPhone 8 plus Space Gray A1864 128GB Tracfone/Straight Talk
# $165.00
# +$13.00 shipping
# =================================
# Apple iPhone 12 Pro - 512GB - Gold - Carrier Unlocked - NO EARPIECE
# $590.00
# +$70.00 shipping
# =================================
# New ListingApple iPhone XS Max - A 1921-Space Gray Cracked  For Parts Only
# $48.00
# +$57.20 shipping
# =================================
# Iphone Lot
# $56.00
# +$42.65 shipping
# =================================
# Apple iPhone 12 PRO - 128GB - GRAY- T-MOBILE - READ DESCRIPTION - 9089
# $333.00
# +$35.00 shipping
# =================================
# New ListingApple iPhone XR - 64GB - White (see Description)
# $135.00
# +$13.00 shipping
# =================================
# Apple iPhone XS - 256GB - Silver (Unlocked) A1920 (CDMA + GSM) WATER DAMAGE
# $210.00
# +$21.00 shipping
# =================================
# Apple iPhone 6s - 64GB - Silver (Unlocked) A1633 (CDMA + GSM)
# $45.00
# +$13.00 shipping
# =================================
# Apple iPhone XR - 64GB - White (Unlocked) A1984 (CDMA + GSM) (Read Description)
# $117.50
# +$21.00 shipping
# =================================
# Apple iPhone 11 Pro - 256GB - Space Gray (Unlocked) A2160 (CDMA + GSM)
# $207.00
# +$25.99 shipping
# =================================
# Apple iPhone XR - 64GB - Black - T-Mobile- CRACKED (S)  SCREEN
# $151.00
# +$70.00 shipping
# =================================
# Apple iPhone SE - 64GB - Rose Gold (Unlocked) A1723 (CDMA + GSM)
# $61.00
# +$21.00 shipping
# =================================
# New ListingApple iPhone 6s Lot Of 17
# $50.00
# +$96.25 shipping
# =================================
# Apple iPhone 11 Pro - 256GB - Midnight Green - Factory Unlocked - NO FACE ID
# $378.96
# +$70.00 shipping
# =================================
# Apple iPhone 11 - 64GB - White  UNLOCKED  A2111 (CDMA + GSM)
# $300.00
# +$21.00 shipping
# =================================
# Apple iPhone 12 Pro - Pacific Blue - (A2341)
# $295.00
# +$13.00 shipping
# =================================
# Apple iPhone XR  - 64GB - WHITE - CRICKET - BAD SCREEN - 8462
# $119.99
# +$35.00 shipping
# =================================
# Apple iPhone XS - 64GB - Gold (Read Description) A1920
# $100.00
# +$21.00 shipping
# =================================
# Apple iPhone 11 - 128gb - Black (T-Mobile) AS IS - screen not working properly
# $152.50
# +$13.00 shipping
# =================================
# Apple iPhone SE 2020 2nd-Gen 64GB Unlocked( slim pack)  sealed
# $308.50
# +$74.95 shipping
# =================================
# Apple iPhone 11 Pro Max - 256GB - Gold (Unlocked) A2161 (CDMA + GSM)
# $569.00
# +$21.00 shipping
# =================================
# Apple iPhone 12 (PRODUCT) RED - 64GB - Unlocked - SCRATCHED BEZEL
# $421.00
# +$70.00 shipping
# =================================
# Apple iPhone 11 Pro - 256GB - Space Gray - Factory Unlocked - LCD DOT
# $405.00
# +$43.00 shipping
# =================================
# Apple iPhone XR - 64GB - Black - Carrier Unlocked - NO SIM
# $175.96
# +$70.00 shipping
# =================================
# Apple iPhone 8 Space Gray A1863 64GB Consumer cellular
# $89.99
# +$13.00 shipping
# =================================
# Apple iPhone 3GS - 16GB - White (AT&T) A1303 (GSM) Fast Ship Good Used
# $34.88
# +$14.00 shipping
# =================================
# Apple iPhone 7 Plus 32GB- Silver (AT&T) A1784 (GSM) IBlason Black Cover
# $300.00
# +$22.00 shipping
# =================================
# New Apple iPhone XR 64GB Factory Unlocked  Smartphone all carriers supported
# $320.00
# +$5.00 shipping
# =================================
# UNLOCKED Apple iPhone 7 PLUS 128GB - Rose Gold AT&T A1784 GSM Verizon T-Mobile
# $139.49
# +$13.00 shipping
# =================================
# New ListingApple iPhone 11 (PRODUCT)RED - 64GB NO POWER FOR PARTS ONLY
# $75.00
# +$57.20 shipping
# =================================
# Apple iPhone 11 Pro (256gb) Unlocked (A2160) PARTS {FMI-OFF} No LCD {iOS13}99%
# $240.00
# +$43.85 shipping
# =================================
# Apple iPhone 1st Generation - 16GB - Black  A1203 (GSM) Clean Powers Up!
# $51.99
# +$13.00 shipping
# =================================
# Apple iPhone 6S A1688 32GB Verizon Space Gray Touchscreen Smartphone (H180)
# $53.95
# +$63.20 shipping
# =================================
# Apple iPhone 8 - 64GB - Space Gray (AT&T) A1905 (GSM)
# $68.00
# +$22.00 shipping
# =================================
# Lot of 12 IPhones **DAMAGED ** For Parts or Repair
# $93.00
# +$66.00 shipping
# =================================
# New ListingApple iPhone 6s Plus - 64GB - Gold (Unlocked) A1687 (CDMA + GSM) Verizon AT&T
# $99.00
# +$66.95 shipping
# =================================
# Apple iPhone 7 A1660 GSM+CDMA 32GB Black (Grade C)
# $76.49
# +$52.53 shipping
# =================================
# Apple iPhone 8 Plus 64GB Factory Unlocked AT&T Verizon T-Mobile Unlocked
# $285.98 to $335.98
# +$80.00 shipping
# =================================
# Apple iPhone XS Factory Unlocked Smartphone T-Mobile AT&T Verizon - A Condition
# $309.98 to $481.98
# +$200.00 shipping
# =================================
# Apple iPhone XS Max - 64GB - Space Grey - Unlocked Smartphone
# $310.00
# +$21.00 shipping
# =================================
# Apple iPhone 12 Pro Max - 256GB - Silver (Unlocked)
# $665.00
# +$36.00 shipping
# =================================
# Apple iPhone 6 Plus - 16GB - Rose Gold (Unlocked)
# $31.00
# +$25.00 shipping
# =================================
# Apple iPhone 4s - 64GB - Black (AT&T) A1387 (CDMA + GSM) - Tested
# $44.95
# +$13.00 shipping
# =================================
# Apple iPhone 7 Plus - 128GB - Rose Gold - Unlocked - Great Condition Sprint
# $112.50
# +$22.00 shipping
# =================================
# Apple iPhone XS Max - 256GB - Space Gray (Unlocked) A1921 (CDMA + GSM)
# $339.00
# +$22.00 shipping
# =================================
# New ListingApple iPhone 11 Pro - 256GB - Space Gray (Unlocked) - CLEAN Esn
# $399.00
# +$20.00 shipping
# =================================
# New ListingIPHONE 5S A1533 32GB WHITE SILVER UNLOCKED GSM WITH ORIGINAL BOX
# $50.00
# +$21.00 shipping
# =================================
# ---------------------------------------------------------------------------
# InvalidOperation                          Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
#       7 price = item.select_one('.s-item__price').text
#       8 shipping = item.select_one('.s-item__shipping').text
# ----> 9 price_decimal = Decimal(price.split(' to ')[0][1:])
#      10 if price_decimal <= max_price:
#      11 	if free_shipping == 'y':
#
# InvalidOperation: [<class 'decimal.ConversionSyntax'>]
